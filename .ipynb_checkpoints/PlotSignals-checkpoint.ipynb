# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from   matplotlib.pyplot import *
import sys
import pylab as pl
import numpy as np
from   copy import copy
import pandas
from astropy.io import fits
from astropy.table import Table, Column
import os.path

from numpy import genfromtxt
from math import *
from astropy.coordinates import SkyCoord
import pandas as pd  
import scipy.stats
from scipy import stats

from scipy import optimize

import seaborn as sns

# %%
'''
multiplicative nstar
CFHT
1.1647339460063184
CS82
0.9572819718802783
DES
0.7186702508075344
HSC
0.8701036471748798
KiDS
0.8215049406709369

additive nstar
CFHT
-0.10977870161861059
CS82
0.03434956641106823
DES
0.2506366735555676
HSC
0.12879223382610674
KiDS
0.16764255972185604
'''

hod_factor=0.8
data=np.loadtxt('hod_model_saito2016_mdpl2.txt')
hod_x=data[:,0]
hod_y=data[:,1]
print(hod_x,hod_y)

#readcol2,'hod_model_saito2016_mdpl2.txt',hod_x,hod_y,format='(F,F)'

#oplot, hod_x, hod_x*hod_y*hod_factor,color=!black, linestyle=2
# DES, CFHT, HSC, CS82, KiDS
#nstar=[0.7186702508075344,1.1647339460063184,0.8701036471748798,0.9572819718802783,0.8215049406709369]
nstar=[0.2506366735555676, -0.10977870161861059, 0.12879223382610674, 0.03434956641106823, 0.16764255972185604]
# Out:
# [ 0.0692234  0.122452   0.216609   0.383168   0.6778     1.19898
#   2.12093    3.75178    6.6366701 11.7398005] [128.7362518  85.16539    55.3456726  34.5954857  20.7462101  11.0788908
#    5.3323693   2.7122905   1.6228064   1.0840461]

# %%
Fig, axes = plt.subplots(2,2,figsize=(9,8))
j=0
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
experiments = ["DES","CFHT","HSC","CS82","KiDS","SDSS"] 
colours=['green','red','darkorange','greenyellow','magenta','turquoise']
markers=['^','o','x','*','s','D']
weight_type = "wtot"
samples = ["LOWZ_0.15_0.31","LOWZ_0.31_0.43","CMASS_0.43_0.54","CMASS_0.54_0.7"]
strings = ["LOWZ 0.15-0.31","LOWZ 0.31-0.43","CMASS 0.43-0.54","CMASS 0.54-0.70"]

for ax, sample in zip(axes.flatten(), samples ):
    
    if j==2:
        experiments=experiments[:-1]
    print(experiments)
    for i,experiment in enumerate(experiments):
        print(i,sample,experiment)
        name = "/Users/alexandraamon/Desktop/Projects/LWB/DScomp/DSResultFiles/"+experiment+"_"+sample+"_"+str(weight_type)+".dat"
        #print(name)
        #CFHT_CMASS_0.54_0.7_wtot.dat
        data=np.loadtxt(name)
        #print(data[:,0])
        #print(data[:,1])
        ax.errorbar(data[:,0],data[:,0]*data[:,1], yerr=data[:,0]*data[:,2],color=colours[i],marker=markers[i],label=experiment,linestyle ='')       
        i+=1
        ax.axvline(x=1.0, ymin=0, ymax=0.85,linestyle='dashed',color='gray',alpha=0.7)
        ax.plot(hod_x, hod_x*hod_y*hod_factor,color='black', linestyle='dashed')
        ax.set_ylim(0,20)
        ax.set_xscale('log')
        ax.set_xlim(xmin=0.03,xmax=20)
        ax.set_xbound(lower=0.03, upper=20)
        ax.tick_params(which='minor', length=4, color='k')
        for tick in ax.xaxis.get_major_ticks():
                tick.label.set_fontsize(16) 
        for tick in ax.yaxis.get_major_ticks():
                tick.label.set_fontsize(16)
    
    ax.text(0.7, 18, strings[j], fontsize=16)
    j+=1

       
axes[0,0].text(0.1, 1.5, "R1", fontsize=16)
axes[0,0].text(2.0, 1.5, "R2", fontsize=16)
axes[0,0].legend(loc='upper left', fontsize=10)
axes[1,0].set_ylabel(r'$R \times \Delta \Sigma \,\,\,\, [\rm{Mpc} \, M_\odot \, \rm{pc^{-2}}]$', fontsize=18)
axes[0,0].set_ylabel(r'$R \times \Delta \Sigma \,\,\,\, [\rm{Mpc} \,  M_\odot \, \rm{pc^{-2}}]$', fontsize=18)
axes[1,0].set_xlabel('R [Mpc/h]', fontsize=18)
axes[1,1].set_xlabel('R [Mpc/h]', fontsize=18)
axes[0,1].set_yticklabels([])
axes[1,1].set_yticklabels([])
axes[0,1].set_xticklabels([])
axes[0,0].set_xticklabels([])
plt.tick_params(axis='y', which='minor')
plt.subplots_adjust(wspace=None, hspace=None)
plt.tight_layout()
#plt.subplots_adjust(left=0.3/10., right=1-0.3/10.0, bottom=0.5/5.0, top=1-0.5/5.0)
plt.savefig("../Figs/DSR"+str(weight_type)+".eps", bbox_inches='tight')
plt.show()
# Out:
# ['DES', 'CFHT', 'HSC', 'CS82', 'KiDS', 'SDSS']
# 0 LOWZ_0.15_0.31 DES
# 1 LOWZ_0.15_0.31 CFHT
# 2 LOWZ_0.15_0.31 HSC
# 3 LOWZ_0.15_0.31 CS82
# 4 LOWZ_0.15_0.31 KiDS
# 5 LOWZ_0.15_0.31 SDSS
# ['DES', 'CFHT', 'HSC', 'CS82', 'KiDS', 'SDSS']
# 0 LOWZ_0.31_0.43 DES
# 1 LOWZ_0.31_0.43 CFHT
# 2 LOWZ_0.31_0.43 HSC
# 3 LOWZ_0.31_0.43 CS82
# 4 LOWZ_0.31_0.43 KiDS
# 5 LOWZ_0.31_0.43 SDSS
# ['DES', 'CFHT', 'HSC', 'CS82', 'KiDS']
# 0 CMASS_0.43_0.54 DES
# 1 CMASS_0.43_0.54 CFHT
# 2 CMASS_0.43_0.54 HSC
# 3 CMASS_0.43_0.54 CS82
# 4 CMASS_0.43_0.54 KiDS
# ['DES', 'CFHT', 'HSC', 'CS82', 'KiDS']
# 0 CMASS_0.54_0.7 DES
# 1 CMASS_0.54_0.7 CFHT
# 2 CMASS_0.54_0.7 HSC
# 3 CMASS_0.54_0.7 CS82
# 4 CMASS_0.54_0.7 KiDS
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %%
Fig, axes = plt.subplots(3,2,figsize=(9,12))
j=0
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
experiments = ["DES","CFHT","HSC","CS82","KiDS","SDSS"] 
colours=['green','red','darkorange','greenyellow','magenta','turquoise']
markers=['^','o','x','*','s','D']
weight_type = "wtot"
samples = ["LOWZ_0.15_0.31","LOWZ_0.31_0.43","CMASS_0.43_0.54","CMASS_0.54_0.7"]
strings = ["LOWZ 0.15-0.31","LOWZ 0.31-0.43","CMASS 0.43-0.54","CMASS 0.54-0.70"]

for ax, sample in zip(axes.flatten(), samples ):
    
    if j==2:
        experiments=experiments[:-1]
    print(experiments)
    for i,experiment in enumerate(experiments):
        print(i,j,sample,experiment)
        name = "/Users/alexandraamon/Desktop/Projects/LWB/DScomp/DSResultFiles/"+experiment+"_"+sample+"_"+str(weight_type)+".dat"
        #print(name)
        #CFHT_CMASS_0.54_0.7_wtot.dat
        data=np.loadtxt(name)
        #print(data[:,0])
        #print(data[:,1])
        ax.errorbar(data[:,0]*(1+0.05*i),data[:,0]*data[:,1], yerr=data[:,0]*data[:,2],color=colours[i],marker=markers[i],label=experiment,linestyle ='')       
        i+=1
        ax.axvline(x=1.0, ymin=0, ymax=0.85,linestyle='dashed',color='gray',alpha=0.7)
        ax.plot(hod_x, hod_x*hod_y*hod_factor,color='black', linestyle='dashed')
        ax.set_ylim(0,20)
        ax.set_xscale('log')
        ax.set_xlim(xmin=0.03,xmax=20)
        ax.set_xbound(lower=0.03, upper=20)
        ax.tick_params(which='minor', length=4, color='k')
        for tick in ax.xaxis.get_major_ticks():
                tick.label.set_fontsize(16) 
        for tick in ax.yaxis.get_major_ticks():
                tick.label.set_fontsize(16)
    
    ax.text(0.995, 18, strings[j], fontsize=16)
    j+=1
    
print("HERE, finished first 4")
print("DETREND NOW")
print(experiments)

'''sample=samples[2]
for i,experiment in enumerate(experiments):
    print(i,j,sample,experiment)
    name = "/Users/alexandraamon/Desktop/Projects/LWB/DScomp/DSResultFiles/"+experiment+"_"+sample+"_"+str(weight_type)+".dat"
    data=np.loadtxt(name)
    ax=axes[2][0]
    ax.errorbar(data[:,0],data[:,0]*data[:,1]*nstar[i], yerr=data[:,0]*data[:,2],color=colours[i],marker=markers[i],label=experiment,linestyle ='')       
    
    ax.axvline(x=1.0, ymin=0, ymax=0.85,linestyle='dashed',color='gray',alpha=0.7)
    ax.set_ylim(0,20)
    ax.set_xscale('log')
    ax.set_xlim(xmin=0.03,xmax=20)
    ax.set_xbound(lower=0.03, upper=20)
    ax.tick_params(which='minor', length=4, color='k')
    for tick in ax.xaxis.get_major_ticks():
            tick.label.set_fontsize(16) 
    for tick in ax.yaxis.get_major_ticks():
            tick.label.set_fontsize(16)
            
    i+=1
ax.text(0.045, 17, 'Nstar trend removed', style='italic', bbox={'facecolor': 'blue', 'alpha': 0.2, 'pad': 10}, fontsize=14)
ax.text(0.995, 18, strings[2], fontsize=16)
'''

sample=samples[3]
for i,experiment in enumerate(experiments):
    print(i,j,sample,experiment)
    name = "/Users/alexandraamon/Desktop/Projects/LWB/DScomp/DSResultFiles/"+experiment+"_"+sample+"_"+str(weight_type)+".dat"
    data=np.loadtxt(name)
    ax=axes[2][1]
    print(1+0.05*i)
    ax.errorbar(data[:,0]*(1+0.05*i),data[:,0]*data[:,1]-nstar[i], yerr=data[:,0]*data[:,2],color=colours[i],marker=markers[i],label=experiment,linestyle ='')       
    
    ax.axvline(x=1.0, ymin=0, ymax=0.85,linestyle='dashed',color='gray',alpha=0.7)
    ax.plot(hod_x, hod_x*hod_y*hod_factor,color='black', linestyle='dashed')
    ax.set_ylim(0,20)
    ax.set_xscale('log')
    ax.set_xlim(xmin=0.03,xmax=20)
    ax.set_xbound(lower=0.03, upper=20)
    ax.tick_params(which='minor', length=4, color='k')
    for tick in ax.xaxis.get_major_ticks():
            tick.label.set_fontsize(16) 
    for tick in ax.yaxis.get_major_ticks():
            tick.label.set_fontsize(16)
            
    i+=1
    
ax.text(0.045, 17, 'Nstar trend removed', style='italic', bbox={'facecolor': 'blue', 'alpha': 0.2, 'pad': 10}, fontsize=14)
ax.text(0.995, 18, strings[3], fontsize=16)

     
axes[0,0].text(0.1, 1.5, "R1", fontsize=16)
axes[0,0].text(2.0, 1.5, "R2", fontsize=16)
axes[0,0].legend(loc='upper left', fontsize=10)
axes[2,0].set_ylabel(r'$R \times \Delta \Sigma \,\,\,\, [\rm{Mpc} \,  M_\odot \, \rm{pc^{-2}}]$', fontsize=18)
axes[1,0].set_ylabel(r'$R \times \Delta \Sigma \,\,\,\, [\rm{Mpc} \, M_\odot \, \rm{pc^{-2}}]$', fontsize=18)
axes[0,0].set_ylabel(r'$R \times \Delta \Sigma \,\,\,\, [\rm{Mpc} \,  M_\odot \, \rm{pc^{-2}}]$', fontsize=18)
axes[2,0].set_xlabel('R [Mpc]', fontsize=18)
axes[2,1].set_xlabel('R [Mpc]', fontsize=18)
axes[0,1].set_yticklabels([])
axes[1,1].set_yticklabels([])
axes[2,1].set_yticklabels([])
axes[0,0].set_xticklabels([])
axes[0,1].set_xticklabels([])
Fig.delaxes(axes[2][0]) 
plt.tick_params(axis='y', which='minor')
plt.subplots_adjust(wspace=None, hspace=None)
plt.tight_layout()
plt.subplots_adjust(left=0.3/10., right=1-0.3/10.0, bottom=0.5/5.0, top=1-0.5/5.0)
filename="../Figs/DSR"+str(weight_type)+"_detrended.pdf"
plt.savefig(filename, bbox_inches='tight')
plt.show()
# Out:
# ['DES', 'CFHT', 'HSC', 'CS82', 'KiDS', 'SDSS']
# 0 0 LOWZ_0.15_0.31 DES
# 1 0 LOWZ_0.15_0.31 CFHT
# 2 0 LOWZ_0.15_0.31 HSC
# 3 0 LOWZ_0.15_0.31 CS82
# 4 0 LOWZ_0.15_0.31 KiDS
# 5 0 LOWZ_0.15_0.31 SDSS
# ['DES', 'CFHT', 'HSC', 'CS82', 'KiDS', 'SDSS']
# 0 1 LOWZ_0.31_0.43 DES
# 1 1 LOWZ_0.31_0.43 CFHT
# 2 1 LOWZ_0.31_0.43 HSC
# 3 1 LOWZ_0.31_0.43 CS82
# 4 1 LOWZ_0.31_0.43 KiDS
# 5 1 LOWZ_0.31_0.43 SDSS
# ['DES', 'CFHT', 'HSC', 'CS82', 'KiDS']
# 0 2 CMASS_0.43_0.54 DES
# 1 2 CMASS_0.43_0.54 CFHT
# 2 2 CMASS_0.43_0.54 HSC
# 3 2 CMASS_0.43_0.54 CS82
# 4 2 CMASS_0.43_0.54 KiDS
# ['DES', 'CFHT', 'HSC', 'CS82', 'KiDS']
# 0 3 CMASS_0.54_0.7 DES
# 1 3 CMASS_0.54_0.7 CFHT
# 2 3 CMASS_0.54_0.7 HSC
# 3 3 CMASS_0.54_0.7 CS82
# 4 3 CMASS_0.54_0.7 KiDS
# HERE, finished first 4
# DETREND NOW
# ['DES', 'CFHT', 'HSC', 'CS82', 'KiDS']
# 0 4 CMASS_0.54_0.7 DES
# 1.0
# 1 4 CMASS_0.54_0.7 CFHT
# 1.05
# 2 4 CMASS_0.54_0.7 HSC
# 1.1
# 3 4 CMASS_0.54_0.7 CS82
# 1.15
# 4 4 CMASS_0.54_0.7 KiDS
# 1.2

# %%
Fig, axes = plt.subplots(1,2,figsize=(11,4.5))
j=0
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
experiments = ["DES","CFHT","HSC","CS82","KiDS"] 
zsouce=[0.59,0.7,0.8,0.57,0.67]
colours=['lightblue','dodgerblue','blue','navy','k']
markers=['^','o','x','*','s','D']
weight_type = "wtot"
samples = ["CMASS_0.43_0.54","CMASS_0.54_0.7"]
strings = ["CMASS 0.43-0.54","CMASS 0.54-0.70"]

for ax, sample in zip(axes.flatten(), samples ):
    
    if j==2:
        experiments=experiments[:-1]
    print(experiments)
    for i,experiment in enumerate(experiments):
        print(i,j,sample,experiment)
        name = "/Users/alexandraamon/Desktop/Projects/LWB/DScomp/DSResultFiles/"+experiment+"_"+sample+"_"+str(weight_type)+".dat"
        #print(name)
        #CFHT_CMASS_0.54_0.7_wtot.dat
        data=np.loadtxt(name)
        #print(data[:,0])
        #print(data[:,1])
        ax.errorbar(data[:,0]*(1+0.05*i),data[:,0]*data[:,1], yerr=data[:,0]*data[:,2],color=colours[i],marker=markers[i],label=experiment,linestyle ='')       
        i+=1
        ax.axvline(x=1.0, ymin=0, ymax=0.85,linestyle='dashed',color='gray',alpha=0.7)
        ax.plot(hod_x, hod_x*hod_y*hod_factor,color='black', linestyle='dashed')
        ax.set_ylim(0,20)
        ax.set_xscale('log')
        ax.set_xlim(xmin=0.03,xmax=20)
        ax.set_xbound(lower=0.03, upper=20)
        ax.tick_params(which='minor', length=4, color='k')
        for tick in ax.xaxis.get_major_ticks():
                tick.label.set_fontsize(16) 
        for tick in ax.yaxis.get_major_ticks():
                tick.label.set_fontsize(16)
    
    ax.text(0.995, 18, strings[j], fontsize=16)
    j+=1
    
print("HERE, finished first 4")
print("DETREND NOW")
print(experiments)


sample=samples[1]
for i,experiment in enumerate(experiments):
    print(i,j,sample,experiment)
    name = "/Users/alexandraamon/Desktop/Projects/LWB/DScomp/DSResultFiles/"+experiment+"_"+sample+"_"+str(weight_type)+".dat"
    data=np.loadtxt(name)
    ax=axes[1]
    ax.errorbar(data[:,0]*(1+0.05*i),data[:,0]*data[:,1]-nstar[i], yerr=data[:,0]*data[:,2],color=colours[i],marker=markers[i],label=experiment,linestyle ='')       
    
    ax.axvline(x=1.0, ymin=0, ymax=0.85,linestyle='dashed',color='gray',alpha=0.7)
    ax.plot(hod_x, hod_x*hod_y*hod_factor,color='black', linestyle='dashed')
    ax.set_ylim(0,20)
    ax.set_xscale('log')
    ax.set_xlim(xmin=0.03,xmax=20)
    ax.set_xbound(lower=0.03, upper=20)
    ax.tick_params(which='minor', length=4, color='k')
    for tick in ax.xaxis.get_major_ticks():
            tick.label.set_fontsize(16) 
    for tick in ax.yaxis.get_major_ticks():
            tick.label.set_fontsize(16)
            
    i+=1
    
ax.text(0.045, 17, 'Nstar trend removed', style='italic', bbox={'facecolor': 'blue', 'alpha': 0.2, 'pad': 10}, fontsize=14)
ax.text(0.995, 18, strings[1], fontsize=16)

     
axes[0].text(0.1, 1.5, "R1", fontsize=16)
axes[0].text(2.0, 1.5, "R2", fontsize=16)
axes[0].legend(loc='upper left', fontsize=10)
axes[0].set_ylabel(r'$R \times \Delta \Sigma \,\,\,\, [\rm{Mpc} \,  M_\odot \, \rm{pc^{-2}}]$', fontsize=18)
#axes[1].set_ylabel(r'$R \times \Delta \Sigma \,\,\,\, [\rm{Mpc} \, M_\odot \, \rm{pc^{-2}}]$', fontsize=18)
axes[0].set_xlabel('R [Mpc]', fontsize=18)
axes[1].set_xlabel('R [Mpc]', fontsize=18)
#axes[0,1].set_yticklabels([])
#axes[1,1].set_yticklabels([])
##axes[2,1].set_yticklabels([])
#axes[0,0].set_xticklabels([])
#axes[0,1].set_xticklabels([])
#Fig.delaxes(axes[2][0]) 
plt.tick_params(axis='y', which='minor')
plt.subplots_adjust(wspace=None, hspace=None)
plt.tight_layout()
plt.subplots_adjust(left=0.3/10., right=1-0.3/10.0, bottom=0.5/5.0, top=1-0.5/5.0)
filename="../Figs/DSR"+str(weight_type)+"_detrended_CMASSonly_zcoloured.pdf"
plt.savefig(filename, bbox_inches='tight')
plt.show()
# Out:
# ['DES', 'CFHT', 'HSC', 'CS82', 'KiDS']
# 0 0 CMASS_0.43_0.54 DES
# 1 0 CMASS_0.43_0.54 CFHT
# 2 0 CMASS_0.43_0.54 HSC
# 3 0 CMASS_0.43_0.54 CS82
# 4 0 CMASS_0.43_0.54 KiDS
# ['DES', 'CFHT', 'HSC', 'CS82', 'KiDS']
# 0 1 CMASS_0.54_0.7 DES
# 1 1 CMASS_0.54_0.7 CFHT
# 2 1 CMASS_0.54_0.7 HSC
# 3 1 CMASS_0.54_0.7 CS82
# 4 1 CMASS_0.54_0.7 KiDS
# HERE, finished first 4
# DETREND NOW
# ['DES', 'CFHT', 'HSC', 'CS82', 'KiDS']
# 0 2 CMASS_0.54_0.7 DES
# 1 2 CMASS_0.54_0.7 CFHT
# 2 2 CMASS_0.54_0.7 HSC
# 3 2 CMASS_0.54_0.7 CS82
# 4 2 CMASS_0.54_0.7 KiDS

# %%
Fig, axes = plt.subplots(3,2,figsize=(9,12))
j=0
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
experiments = ["DES","CFHT","HSC","CS82","KiDS","SDSS"] 
colours=['green','red','darkorange','greenyellow','magenta','turquoise']
markers=['^','o','x','*','s','D']
weight_type = "wtot"
samples = ["LOWZ_0.15_0.31","LOWZ_0.31_0.43","CMASS_0.43_0.54","CMASS_0.54_0.7"]
strings = ["LOWZ 0.15-0.31","LOWZ 0.31-0.43","CMASS 0.43-0.54","CMASS 0.54-0.70"]

for ax, sample in zip(axes.flatten(), samples ):
    
    if j==2:
        experiments=experiments[:-1]
    print(experiments)
    for i,experiment in enumerate(experiments):
        print(i,j,sample,experiment)
        name = "/Users/alexandraamon/Desktop/Projects/LWB/DScomp/DSResultFiles/"+experiment+"_"+sample+"_"+str(weight_type)+".dat"
        #print(name)
        #CFHT_CMASS_0.54_0.7_wtot.dat
        data=np.loadtxt(name)
        #print(data[:,0])
        #print(data[:,1])
        ax.errorbar(data[:,0],data[:,0]*data[:,1], yerr=data[:,0]*data[:,2],color=colours[i],marker=markers[i],label=experiment,linestyle ='')       
        i+=1
        ax.axvline(x=1.0, ymin=0, ymax=0.85,linestyle='dashed',color='gray',alpha=0.7)
        ax.plot(hod_x, hod_x*hod_y*hod_factor,color='black', linestyle='dashed')
        ax.set_ylim(0,20)
        ax.set_xscale('log')
        ax.set_xlim(xmin=0.03,xmax=20)
        ax.set_xbound(lower=0.03, upper=20)
        ax.tick_params(which='minor', length=4, color='k')
        for tick in ax.xaxis.get_major_ticks():
                tick.label.set_fontsize(16) 
        for tick in ax.yaxis.get_major_ticks():
                tick.label.set_fontsize(16)
    
    ax.text(0.995, 18, strings[j], fontsize=16)
    j+=1
    
print("HERE, finished first 4")
print("DETREND NOW")
print(experiments)


sample=samples[3]
for i,experiment in enumerate(experiments):
    print(i,j,sample,experiment)
    name = "/Users/alexandraamon/Desktop/Projects/LWB/DScomp/DSResultFiles/"+experiment+"_"+sample+"_"+str(weight_type)+".dat"
    data=np.loadtxt(name)
    ax=axes[2][1]
    ax.errorbar(data[:,0],data[:,0]*data[:,1]-nstar[i], yerr=data[:,0]*data[:,2],color=colours[i],marker=markers[i],label=experiment,linestyle ='')       
    
    ax.axvline(x=1.0, ymin=0, ymax=0.85,linestyle='dashed',color='gray',alpha=0.7)
    ax.plot(hod_x, hod_x*hod_y,color='black', linestyle='dashed')
    ax.set_ylim(0,20)
    ax.set_xscale('log')
    ax.set_xlim(xmin=0.03,xmax=20)
    ax.set_xbound(lower=0.03, upper=20)
    ax.tick_params(which='minor', length=4, color='k')
    for tick in ax.xaxis.get_major_ticks():
            tick.label.set_fontsize(16) 
    for tick in ax.yaxis.get_major_ticks():
            tick.label.set_fontsize(16)
            
    i+=1
    
ax.text(0.045, 17, 'Nstar trend removed', style='italic', bbox={'facecolor': 'blue', 'alpha': 0.2, 'pad': 10}, fontsize=14)
ax.text(0.995, 18, strings[3], fontsize=16)

       
axes[0,0].text(0.1, 1.5, "R1", fontsize=16)
axes[0,0].text(2.0, 1.5, "R2", fontsize=16)
axes[0,0].legend(loc='upper left', fontsize=10)
axes[2,0].set_ylabel(r'$R \times \Delta \Sigma \,\,\,\, [\rm{Mpc} \,  M_\odot \, \rm{pc^{-2}}]$', fontsize=18)
axes[1,0].set_ylabel(r'$R \times \Delta \Sigma \,\,\,\, [\rm{Mpc} \, M_\odot \, \rm{pc^{-2}}]$', fontsize=18)
axes[0,0].set_ylabel(r'$R \times \Delta \Sigma \,\,\,\, [\rm{Mpc} \,  M_\odot \, \rm{pc^{-2}}]$', fontsize=18)
axes[2,0].set_xlabel('R [Mpc]', fontsize=18)
axes[2,1].set_xlabel('R [Mpc]', fontsize=18)
axes[0,1].set_yticklabels([])
axes[1,1].set_yticklabels([])
axes[2,1].set_yticklabels([])
axes[0,0].set_xticklabels([])
axes[0,1].set_xticklabels([])
plt.tick_params(axis='y', which='minor')
plt.subplots_adjust(wspace=None, hspace=None)
plt.tight_layout()
plt.subplots_adjust(left=0.3/10., right=1-0.3/10.0, bottom=0.5/5.0, top=1-0.5/5.0)
filename="../Figs/DSR"+str(weight_type)+"_detrended.png"
plt.savefig(filename, bbox_inches='tight')
plt.show()
# Out:
# ['DES', 'CFHT', 'HSC', 'CS82', 'KiDS', 'SDSS']
# 0 0 LOWZ_0.15_0.31 DES
# 1 0 LOWZ_0.15_0.31 CFHT
# 2 0 LOWZ_0.15_0.31 HSC
# 3 0 LOWZ_0.15_0.31 CS82
# 4 0 LOWZ_0.15_0.31 KiDS
# 5 0 LOWZ_0.15_0.31 SDSS
# ['DES', 'CFHT', 'HSC', 'CS82', 'KiDS', 'SDSS']
# 0 1 LOWZ_0.31_0.43 DES
# 1 1 LOWZ_0.31_0.43 CFHT
# 2 1 LOWZ_0.31_0.43 HSC
# 3 1 LOWZ_0.31_0.43 CS82
# 4 1 LOWZ_0.31_0.43 KiDS
# 5 1 LOWZ_0.31_0.43 SDSS
# ['DES', 'CFHT', 'HSC', 'CS82', 'KiDS']
# 0 2 CMASS_0.43_0.54 DES
# 1 2 CMASS_0.43_0.54 CFHT
# 2 2 CMASS_0.43_0.54 HSC
# 3 2 CMASS_0.43_0.54 CS82
# 4 2 CMASS_0.43_0.54 KiDS
# ['DES', 'CFHT', 'HSC', 'CS82', 'KiDS']
# 0 3 CMASS_0.54_0.7 DES
# 1 3 CMASS_0.54_0.7 CFHT
# 2 3 CMASS_0.54_0.7 HSC
# 3 3 CMASS_0.54_0.7 CS82
# 4 3 CMASS_0.54_0.7 KiDS
# HERE, finished first 4
# DETREND NOW
# ['DES', 'CFHT', 'HSC', 'CS82', 'KiDS']
# 0 4 CMASS_0.54_0.7 DES
# 1 4 CMASS_0.54_0.7 CFHT
# 2 4 CMASS_0.54_0.7 HSC
# 3 4 CMASS_0.54_0.7 CS82
# 4 4 CMASS_0.54_0.7 KiDS
